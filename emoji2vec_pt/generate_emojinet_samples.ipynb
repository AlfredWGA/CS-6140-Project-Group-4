# %%
import spacy
import pandas as pd
import numpy as np
from pathlib import Path

# %%
current_path = Path(".").resolve()
project_path = current_path.parent

# %%
def load_vocab(fpath):
    """
    Load the emoji vocab.
    """
    vocab = {}
    with open(fpath, "r", encoding="utf-8") as f:
        for idx, line in enumerate(f):
            emoji = line.strip()
            vocab[emoji] = idx
    
    return vocab

# %%
vocab = load_vocab(current_path / "data" / "vocab.txt")

# %%
list(vocab)[:10]
# Out:
# ['PAD', '🏊', '💃🏻', '🅱️', '⬛', '☔️', '📱', '🇯🇲', '👶🏿', '3⃣️']

# %%
nlp = spacy.load("en_core_web_md")

# %%
import json
import emoji
import string
import re

# A dict that maps the emoji's unicode to its info
emojinet = {}

with open(current_path / '..' / 'preprocess_emojinet' / 'emojis.json' / 'emojis.json', encoding='utf-8') as f:
    # for emoji_dict in json.loads(f.read()):
    #     # If the emoji doeasn't have a shortcode
    #     if "shortcode" not in emoji_dict or emoji_dict["shortcode"] is None:
    #         c_list = []
    #         for unicode in emoji_dict["unicode"].split(" "):
    #             c_list.append(chr(int(unicode.replace('U+', ''), 16)))

    #         # if len(emoji_dict["unicode"].split(" ")) > 1:
    #         #     unicode = emoji_dict["unicode"].split(" ")[1]
    #         #     c = chr(int(unicode.replace('U+', ''), 16))
                
            
    #         # unicode = emoji_dict["unicode"].split(" ")[0]
    #         # c = chr(int(unicode.replace('U+', ''), 16))
    #         c_list = [c for c in c_list if c in vocab]
    #         if len(c_list) == 0:
    #             continue
    #     else: 
    #         c_list = [emoji.emojize(emoji_dict["shortcode"], use_aliases=True)]

    #     for c in c_list:
    #         emojinet[c] = {'name': emoji_dict['name'], 
    #         'keywords': emoji_dict['keywords'],
    #         'definition': emoji_dict['definition']}
    for emoji_dict in json.loads(f.read()):
        token_list = []
        desc = re.sub(r'^https?:\/\/.*[\r\n]*', '', emoji_dict['definition'])   # Remove the URL
        for token in nlp(desc):
            if token.text in spacy.lang.en.stop_words.STOP_WORDS or token.text in string.punctuation:
                continue
            token_list.append(token.text)
        
        # Usually 
        token_list = token_list[:-1]
        
        desc = " ".join(token_list)
        emojinet[emoji_dict["unicode"]] = {'name': emoji_dict['name'], 
            'keywords': emoji_dict['keywords'],
            'definition': desc}

# %%
emojinet
# Out:
# {'U+1F645 U+1F3FF U+200D U+2640 U+FE0F': {'name': 'woman gesturing NO: dark skin tone',
#   'keywords': ['dark skin tone',
#    'hand',
#    'forbidden',
#    'gesture',
#    'woman',
#    'prohibited',
#    'no'],
#   'definition': 'The Woman Gesturing Not OK Type-6 emoji sequence Face With No Good Gesture Emoji Modifier Fitzpatrick Type-6 Female S'},
#  'U+1F482 U+1F3FF U+200D U+2640 U+FE0F': {'name': 'woman guard: dark skin tone',
#   'keywords': ['dark skin tone', 'woman', 'guard'],
#   'definition': 'The Female Guard Type-6 emoji sequence Guardsman Emoji Modifier Fitzpatrick Type-6 Female Sign Variation Select'},
#  'U+1F3C3 U+200D U+2640 U+FE0F': {'name': 'woman running',
#   'keywords': ['racing', 'running', 'woman', 'marathon'],
#   'definition': 'The female version \xa0 Runner emoji The Woman Running emoji sequence Runner Female Sign Variation Selector-16'},
#  'U+1F938 U+1F3FC U+200D U+2640 U+FE0F': {'name': 'woman cartwheeling: medium-light skin tone',
#   'keywords': ['gymnastics', 'medium-light skin tone', 'woman', 'cartwheel'],
#   'definition': 'The Woman Doing Cartwheel Type-3 emoji sequence Person Doing Cartwheel Emoji Modifier Fitzpatrick Type-3 Female Sign  '},
#  'U+1F3CC U+FE0F U+200D U+2640 U+FE0F': {'name': 'woman golfing',
#   'keywords': ['woman', 'golf'],
#   'definition': 'The female version \xa0 Golfer \xa0 emoji The Woman Golfing emoji sequence Golfer Variation Selector-16 Female Sign'},
#  'U+0030 U+FE0F U+20E3': {'name': 'keycap: 0',
#   'keywords': ['keycap'],
#   'definition': 'Keycap Digit Zero approved Unicode 3.0 1999 added Emoji 3.0 2016 Copy paste emoji Copy'},
#  'U+1F3C3 U+1F3FE U+200D U+2640 U+FE0F': {'name': 'woman running: medium-dark skin tone',
#   'keywords': ['racing',
#    'running',
#    'medium-dark skin tone',
#    'woman',
#    'marathon'],
#   'definition': 'The Woman Running Type-5 emoji sequence Runner Emoji Modifier Fitzpatrick Type-5 Female Sign Variation Selector'},
#  'U+1F468 U+1F3FE U+200D U+1F33E': {'name': 'man farmer: medium-dark skin tone',
#   'keywords': ['farmer',
#    'gardener',
#    'medium-dark skin tone',
#    'rancher',
#    'man'],
#   'definition': 'The Male Farmer Type-5 emoji sequence Man Emoji Modifier Fitzpatrick Type-5 Ear Rice emojis These combine'},
#  'U+1F44F U+1F3FF': {'name': 'clapping hands: dark skin tone',
#   'keywords': ['dark skin tone', 'clap', 'hand'],
#   'definition': 'This version Clapping Hands emoji Dark Skin Tone applied displayed Black Skin Tone supported platform'},
#  'U+1F44F U+1F3FE': {'name': 'clapping hands: medium-dark skin tone',
#   'keywords': ['clap', 'hand', 'medium-dark skin tone'],
#   'definition': 'This version Clapping Hands emoji Medium dark Skin Tone applied displayed Dark Brown Skin Tone suppor'},
#  'U+1F44F U+1F3FD': {'name': 'clapping hands: medium skin tone',
#   'keywords': ['clap', 'hand', 'medium skin tone'],
#   'definition': 'This version Clapping Hands emoji Medium Skin Tone applied displayed Moderate Brown Skin Tone support'},
#  'U+1F44F U+1F3FC': {'name': 'clapping hands: medium-light skin tone',
#   'keywords': ['clap', 'hand', 'medium-light skin tone'],
#   'definition': 'This version Clapping Hands emoji Medium light Skin Tone applied displayed Cream White Skin Tone supp'},
#  'U+1F44F U+1F3FB': {'name': 'clapping hands: light skin tone',
#   'keywords': ['clap', 'light skin tone', 'hand'],
#   'definition': 'This version Clapping Hands emoji Light Skin Tone applied displayed Pale Skin Tone supported platform'},
#  'U+1F6B6 U+1F3FB U+200D U+2640 U+FE0F': {'name': 'woman walking: light skin tone',
#   'keywords': ['walk', 'light skin tone', 'woman', 'hike'],
#   'definition': 'The Woman Walking Type-1 2 emoji sequence Pedestrian Emoji Modifier Fitzpatrick Type-1 2 Female Sign Variation  '},
#  'U+1F468 U+1F3FC U+200D U+1F692': {'name': 'man firefighter: medium-light skin tone',
#   'keywords': ['firetruck', 'medium-light skin tone', 'firefighter', 'man'],
#   'definition': 'The Male Firefighter Type-3 emoji sequence Man Emoji Modifier Fitzpatrick Type-3 Fire Engine emojis These co'},
#  'U+1F991': {'name': 'squid',
#   'keywords': ['squid', 'molusc', 'food'],
#   'definition': 'Squid approved Unicode 9.0 2016 added Emoji 3.0 2016 Copy paste emoji Copy New \xa0 iOS 10.2'},
#  'U+1F990': {'name': 'shrimp',
#   'keywords': ['small', 'shrimp', 'shellfish', 'food'],
#   'definition': 'Shrimp approved Unicode 9.0 2016 added Emoji 3.0 2016 Copy paste emoji Copy New \xa0 iOS 10.2'},
#  'U+1F98F': {'name': 'rhinoceros',
#   'keywords': ['rhinoceros'],
#   'definition': 'A rhinoceros displayed entire animal face Rhinoceros approved Unicode 9.0 2016 added E'},
#  'U+1F98E': {'name': 'lizard',
#   'keywords': ['lizard', 'reptile'],
#   'definition': 'A small lizard shown green brown colors Lizard approved Unicode 9.0 2016 added Emoji 3.0  '},
#  'U+1F98D': {'name': 'gorilla',
#   'keywords': ['gorilla'],
#   'definition': 'A gorilla displayed entire animal face Gorilla approved Unicode 9.0 2016 added Emoji 3'},
#  'U+1F98C': {'name': 'deer',
#   'keywords': ['deer'],
#   'definition': 'Deer approved Unicode 9.0 2016 added Emoji 3.0 2016 Copy paste emoji Copy New \xa0 iOS 10.2'},
#  'U+1F98B': {'name': 'butterfly',
#   'keywords': ['pretty', 'insect', 'butterfly'],
#   'definition': 'A butterfly shown wings spread Commonly displayed \xa0 monarch butterfly orange black wings Butterfly approved  '},
#  'U+1F98A': {'name': 'fox face',
#   'keywords': ['fox', 'face'],
#   'definition': 'A fox face shown pointy ears At small sizes difficult discern wolf face Fox Face approved Unicode  '},
#  'U+1F468 U+1F3FC U+200D U+1F680': {'name': 'man astronaut: medium-light skin tone',
#   'keywords': ['rocket', 'medium-light skin tone', 'astronaut', 'man'],
#   'definition': 'The Male Astronaut Type-3 emoji sequence Man Emoji Modifier Fitzpatrick Type-3 Rocket emojis These combined  '},
#  'U+1F989': {'name': 'owl',
#   'keywords': ['wise', 'owl', 'bird'],
#   'definition': 'An owl shown facing forward large eyes yellow beak Owl approved Unicode 9.0 2016 added Emoji 3.0  '},
#  'U+1F988': {'name': 'shark',
#   'keywords': ['shark', 'fish'],
#   'definition': 'A shark swimming ocean displayed blue gray tone Shark approved Unicode 9.0 2016 added Emoj'},
#  'U+1F987': {'name': 'bat',
#   'keywords': ['bat', 'vampire'],
#   'definition': 'A black bat enjoys dark shown spreading wings Bat approved Unicode 9.0 2016 added Emoji 3.0 2016'},
#  'U+1F986': {'name': 'duck',
#   'keywords': ['duck', 'bird'],
#   'definition': 'A bird enjoys spending time water Shown platforms \xa0 mallard \xa0 brown white green colors Samsung displays thi'},
#  'U+1F985': {'name': 'eagle',
#   'keywords': ['eagle', 'bird'],
#   'definition': 'An eagle soaring sky Also national embled United States Eagle approved Unicode 9.0 2016 add'},
#  'U+1F984': {'name': 'unicorn face',
#   'keywords': ['face', 'unicorn'],
#   'definition': 'A mythical creature generally depicted white horse \xa0 long horn Unicorn Face approved Unicode 8.0 2015 adde'},
#  'U+1F469 U+200D U+1F466 U+200D U+1F466': {'name': 'family: woman, boy, boy',
#   'keywords': ['family', 'boy', 'woman'],
#   'definition': 'The Family Woman Boy Boy emoji sequence Woman Boy Boy emojis These combined zero width joiner betw'},
#  'U+1F983': {'name': 'turkey',
#   'keywords': ['turkey'],
#   'definition': 'A turkey bird \xa0 cooked eaten Thanksgiving Christmas This emoji displays live turkey similar presentat'},
#  'U+1F982': {'name': 'scorpion',
#   'keywords': ['scorpio', 'zodiac', 'scorpius'],
#   'definition': 'A scorpion shown legs upright rail May relation zodiac sign Scorpius Scorpion approved par'},
#  'U+1F487 U+1F3FE U+200D U+2642 U+FE0F': {'name': 'man getting haircut: medium-dark skin tone',
#   'keywords': ['medium-dark skin tone', 'man', 'haircut'],
#   'definition': 'The Man Getting Haircut Type-5 emoji sequence Haircut Emoji Modifier Fitzpatrick Type-5 Male Sign Variation Sel'},
#  'U+1F981': {'name': 'lion face',
#   'keywords': ['lion', 'face', 'zodiac', 'leo'],
#   'definition': 'The face lion referred king jungle Displays cute cartoon style face Apple artwork appears'},
#  'U+1F468 U+200D U+1F52C': {'name': 'man scientist',
#   'keywords': ['mathematician',
#    'engineer',
#    'physicist',
#    'chemist',
#    'biologist',
#    'scientist',
#    'man'],
#   'definition': 'The Man Scientist emoji sequence Man Microscope emojis These combined zero width joiner char'},
#  'U+1F980': {'name': 'crab',
#   'keywords': ['cancer', 'zodiac'],
#   'definition': 'A crab shown claws May relation zodiac symbol cancer Crab approved Unicode 8.0 2015 adde'},
#  'U+1F468 U+1F3FD U+200D U+2696 U+FE0F': {'name': 'man judge: medium skin tone',
#   'keywords': ['justice', 'scales', 'medium skin tone', 'man'],
#   'definition': 'The Male Judge Type-4 emoji sequence Man Emoji Modifier Fitzpatrick Type-4 Scales Variation Selector-16 emojis'},
#  'U+1F468 U+200D U+1F527': {'name': 'man mechanic',
#   'keywords': ['electrician', 'tradesperson', 'plumber', 'mechanic', 'man'],
#   'definition': 'The Man Mechanic emoji sequence Man Wrench emojis These combined zero width joiner character'},
#  'U+1F469 U+200D U+1F467': {'name': 'family: woman, girl',
#   'keywords': ['family', 'woman', 'girl'],
#   'definition': 'The Family Woman Girl emoji sequence Woman Girl emojis These combined zero width joiner ch'},
#  'U+1F469 U+200D U+1F466': {'name': 'family: woman, boy',
#   'keywords': ['family', 'boy', 'woman'],
#   'definition': 'The Family Woman Boy emoji sequence Woman Boy emojis These combined zero width joiner char'},
#  'U+1F469 U+1F3FE U+200D U+1F52C': {'name': 'woman scientist: medium-dark skin tone',
#   'keywords': ['mathematician',
#    'engineer',
#    'medium-dark skin tone',
#    'woman',
#    'physicist',
#    'chemist',
#    'biologist',
#    'scientist'],
#   'definition': 'The Female Scientist Type-5 emoji sequence Woman Emoji Modifier Fitzpatrick Type-5 Microscope emojis These c'},
#  'U+1F469 U+1F3FE U+200D U+1F527': {'name': 'woman mechanic: medium-dark skin tone',
#   'keywords': ['electrician',
#    'tradesperson',
#    'plumber',
#    'medium-dark skin tone',
#    'woman',
#    'mechanic'],
#   'definition': 'The Female Mechanic Type-5 emoji sequence Woman Emoji Modifier Fitzpatrick Type-5 Wrench emojis These combin'},
#  'U+1F64B U+1F3FC U+200D U+2640 U+FE0F': {'name': 'woman raising hand: medium-light skin tone',
#   'keywords': ['medium-light skin tone', 'gesture', 'woman', 'raising hand'],
#   'definition': 'The Woman Raising Hand Type-3 emoji sequence Happy Person Raising One Hand Emoji Modifier Fitzpatrick Type-3 Female S'},
#  'U+1F95E': {'name': 'pancakes',
#   'keywords': ['pancake', 'hotcake', 'food', 'crêpe'],
#   'definition': 'A stack pancakes shown maple syrup dressings May relation Shrove Tuesday Pancakes approved  '},
#  'U+1F95D': {'name': 'kiwi fruit',
#   'keywords': ['fruit', 'kiwi', 'food'],
#   'definition': 'The kiwifruit emoji known \xa0 Chinese gooseberry shown brown skin sliced open \xa0 green flesh black seeds th'},
#  'U+1F95C': {'name': 'peanuts',
#   'keywords': ['vegetable', 'peanut', 'nut', 'food'],
#   'definition': 'Peanuts approved Unicode 9.0 2016 added Emoji 3.0 2016 Copy paste emoji Copy New \xa0 iOS 10.2'},
#  'U+1F95B': {'name': 'glass of milk',
#   'keywords': ['drink', 'glass', 'milk'],
#   'definition': 'Glass Milk approved Unicode 9.0 2016 added Emoji 3.0 2016 Copy paste emoji Copy New \xa0 iOS 10.2'},
#  'U+1F6B5 U+200D U+2642 U+FE0F': {'name': 'man mountain biking',
#   'keywords': ['bicycle', 'cyclist', 'bike', 'mountain', 'man'],
#   'definition': 'The male version \xa0 Mountain Bicyclist \xa0 emoji Currently identical appearance non gendered base emoji The Man Mountain Biki'},
#  'U+1F95A': {'name': 'egg',
#   'keywords': ['egg', 'food'],
#   'definition': 'An egg commonly displayed chicken egg white light brown shell May cooking Egg approved Unic'},
#  'U+1F959': {'name': 'stuffed flatbread',
#   'keywords': ['stuffed', 'falafel', 'gyro', 'flatbread', 'kebab', 'food'],
#   'definition': 'Flatbread containing items salad sliced meat falafel A fast food item popular parts middle east May come'},
#  'U+1F958': {'name': 'shallow pan of food',
#   'keywords': ['shallow', 'pan', 'paella', 'food', 'casserole'],
#   'definition': 'A pan food \xa0 commonly associated \xa0 paella rice dish \xa0 originating \xa0 Valencia \xa0 Spain Shallow Pan Food approved'},
#  'U+1F957': {'name': 'green salad',
#   'keywords': ['salad', 'green', 'food'],
#   'definition': 'A bowl healthy salad containing lettuce tomato salad items cucumber Green Salad approved Unicode 9.0'},
#  'U+1F956': {'name': 'baguette bread',
#   'keywords': ['french', 'bread', 'baguette', 'food'],
#   'definition': 'Baguette Bread approved Unicode 9.0 2016 added Emoji 3.0 2016 Copy paste emoji Copy New \xa0 iOS 10'},
#  'U+1F955': {'name': 'carrot',
#   'keywords': ['carrot', 'vegetable', 'food'],
#   'definition': 'An orange carrot shown raw green leaves attached Carrot approved Unicode 9.0 2016 added Emoji 3.0 2016 C'},
#  'U+1F954': {'name': 'potato',
#   'keywords': ['vegetable', 'potato', 'food'],
#   'definition': 'An uncooked potato baking larger meal Not confused roasted sweet potato Potato'},
#  'U+1F953': {'name': 'bacon',
#   'keywords': ['bacon', 'meat', 'food'],
#   'definition': 'Strips cooked bacon popular range dishes accompany eggs Bacon approved Unicode 9.0 2016'},
#  'U+1F952': {'name': 'cucumber',
#   'keywords': ['vegetable', 'cucumber', 'pickle', 'food'],
#   'definition': 'A cucumber emoji pickle gherkin Cucumber approved Unicode 9.0 2016 added Em'},
#  'U+1F951': {'name': 'avocado',
#   'keywords': ['fruit', 'avocado', 'food'],
#   'definition': 'A ripe avocado cut open ready served Displayed \xa0 cut half stone showing Avocado approved Unicode 9.0  '},
#  'U+1F486 U+1F3FC U+200D U+2640 U+FE0F': {'name': 'woman getting massage: medium-light skin tone',
#   'keywords': ['medium-light skin tone', 'woman', 'face', 'massage'],
#   'definition': 'The Woman Getting Face Massage Type-3 emoji sequence Face Massage Emoji Modifier Fitzpatrick Type-3 Female Sign'},
#  'U+1F950': {'name': 'croissant',
#   'keywords': ['french', 'bread', 'crescent roll', 'croissant', 'food'],
#   'definition': 'A pastry crescent shape Popular countries associated France Austria Croissant approved par'},
#  'U+1F94B': {'name': 'martial arts uniform',
#   'keywords': ['uniform', 'martial arts', 'taekwondo', 'judo', 'karate'],
#   'definition': 'A white uniform marital arts judo karate Held material belt \xa0 Known keikogi Japanese Martial Arts'},
#  'U+1F94A': {'name': 'boxing glove',
#   'keywords': ['boxing', 'glove'],
#   'definition': 'A padded boxing glove sport \xa0 boxing Usually red Boxing Glove approved Unicode 9.0 2016 added Emoji'},
#  'U+1F469 U+1F3FF U+200D U+2708 U+FE0F': {'name': 'woman pilot: dark skin tone',
#   'keywords': ['dark skin tone', 'plane', 'woman', 'pilot'],
#   'definition': 'The Female Pilot Type-6 emoji sequence Woman Emoji Modifier Fitzpatrick Type-6 Airplane Variation Selector-16 e'},
#  'U+1F64E U+1F3FD U+200D U+2642 U+FE0F': {'name': 'man pouting: medium skin tone',
#   'keywords': ['pouting', 'gesture', 'medium skin tone', 'man'],
#   'definition': 'The Man Pouting Type-4 emoji sequence Person With Pouting Face Emoji Modifier Fitzpatrick Type-4 Male Sign Vari'},
#  'U+1F949': {'name': '3rd place medal',
#   'keywords': ['bronze', 'third', 'medal'],
#   'definition': '3rd Place Medal approved Unicode 9.0 2016 “ Third Place Medal ” added Emoji 3.0 2016 Copy past'},
#  'U+1F948': {'name': '2nd place medal',
#   'keywords': ['second', 'medal', 'silver'],
#   'definition': '2nd Place Medal approved Unicode 9.0 2016 “ Second Place Medal ” added Emoji 3.0 2016 Copy pas'},
#  'U+1F947': {'name': '1st place medal',
#   'keywords': ['gold', 'medal', 'first'],
#   'definition': '1st Place Medal approved Unicode 9.0 2016 “ First Place Medal ” added Emoji 3.0 2016 Copy past'},
#  'U+1F945': {'name': 'goal net',
#   'keywords': ['goal', 'net'],
#   'definition': 'Goal Net approved Unicode 9.0 2016 added Emoji 3.0 2016 Copy paste emoji Copy New \xa0 iOS 10.2'},
#  'U+1F944': {'name': 'spoon',
#   'keywords': ['tableware', 'spoon'],
#   'definition': 'A silver spoon soft liquid foods soup dessert Often paired fork knife Spoon approve'},
#  'U+1F943': {'name': 'tumbler glass',
#   'keywords': ['whisky', 'liquor', 'shot', 'tumbler', 'glass'],
#   'definition': 'A flat bottomed glass associated drinks whisky rum Shown ice cubes liquid inside glass Tumbler Glass w'},
#  'U+1F942': {'name': 'clinking glasses',
#   'keywords': ['celebrate', 'drink', 'clink', 'glass'],
#   'definition': 'Two glasses flutes champagne clinked celebration Similar clinking beer mugs emoji For bottle sparkling  '},
#  'U+1F941': {'name': 'drum',
#   'keywords': ['drum', 'drumsticks', 'music'],
#   'definition': 'A drum shown drumsticks A percussion instrument likely displayed snare drum Drum approved Unicode  '},
#  'U+1F940': {'name': 'wilted flower',
#   'keywords': ['wilted', 'flower'],
#   'definition': 'A flower died wilted lack water A petal falls ground Wilted Flower approved Unicode 9.0'},
#  'U+26F9 U+1F3FF': {'name': 'person bouncing ball: dark skin tone',
#   'keywords': ['dark skin tone', 'ball'],
#   'definition': 'This version Person Bouncing Ball emoji Dark Skin Tone applied displayed Black Skin Tone supported pla'},
#  'U+26F9 U+1F3FE': {'name': 'person bouncing ball: medium-dark skin tone',
#   'keywords': ['medium-dark skin tone', 'ball'],
#   'definition': 'This version Person Bouncing Ball emoji Medium dark Skin Tone applied displayed Dark Brown Skin Tone s'},
#  'U+26F9 U+1F3FD': {'name': 'person bouncing ball: medium skin tone',
#   'keywords': ['ball', 'medium skin tone'],
#   'definition': 'This version Person Bouncing Ball emoji Medium Skin Tone applied displayed Moderate Brown Skin Tone su'},
#  'U+1F93E': {'name': 'person playing handball',
#   'keywords': ['ball', 'handball'],
#   'definition': 'Person Playing Handball approved Unicode 9.0 2016 “ Handball ” added Emoji 3.0 2016 Copy paste'},
#  'U+26F9 U+1F3FC': {'name': 'person bouncing ball: medium-light skin tone',
#   'keywords': ['medium-light skin tone', 'ball'],
#   'definition': 'This version Person Bouncing Ball emoji Medium light Skin Tone applied displayed Cream White Skin Tone'},
#  'U+1F93D': {'name': 'person playing water polo',
#   'keywords': ['water', 'polo'],
#   'definition': 'A person shown water ball \xa0 playing sport water polo \xa0  Person Playing Water Polo approved Unicode 9.0 2016'},
#  'U+26F9 U+1F3FB': {'name': 'person bouncing ball: light skin tone',
#   'keywords': ['light skin tone', 'ball'],
#   'definition': 'This version Person Bouncing Ball emoji Light Skin Tone applied displayed Pale Skin Tone supported pla'},
#  'U+1F93C': {'name': 'people wrestling',
#   'keywords': ['wrestler', 'wrestle'],
#   'definition': 'Two people sport wrestling People Wrestling approved Unicode 9.0 2016 “ Wrestlers ” added E'},
#  'U+1F93A': {'name': 'person fencing',
#   'keywords': ['sword', 'fencing', 'fencer'],
#   'definition': 'A person shown sport fencing Rapier style sword mask protective clothing Person Fencing approved Uni'},
#  'U+1F575 U+1F3FF U+200D U+2640 U+FE0F': {'name': 'woman detective: dark skin tone',
#   'keywords': ['dark skin tone', 'sleuth', 'spy', 'woman', 'detective'],
#   'definition': 'The Female Sleuth Type-6 emoji sequence Sleuth Spy Emoji Modifier Fitzpatrick Type-6 Female Sign Variation S'},
#  'U+1F939': {'name': 'person juggling',
#   'keywords': ['skill', 'multitask', 'juggle', 'balance'],
#   'definition': 'A person juggling colored balls The person shown emoji generally appearance man wears ha'},
#  'U+1F938': {'name': 'person cartwheeling',
#   'keywords': ['gymnastics', 'cartwheel'],
#   'definition': 'A person cartwheel representing sport gymnastics Person Cartwheeling approved Unicode 9.0 2016  '},
#  'U+1F46F U+200D U+2642 U+FE0F': {'name': 'men with bunny ears partying',
#   'keywords': ['bunny ear', 'partying', 'men', 'dancer'],
#   'definition': 'The male version \xa0 Woman With Bunny Ears emoji The Men With Bunny Ears Partying emoji sequence Woman With Bunny Ears'},
#  'U+1F937': {'name': 'person shrugging',
#   'keywords': ['indifference', 'shrug', 'ignorance', 'doubt'],
#   'definition': 'A person shrugging shoulders indicate lack knowledge particular topic lack care result situati'},
#  'U+1F936': {'name': 'Mrs. Claus',
#   'keywords': ['claus', 'mother', 'mrs.', 'celebration', 'christmas'],
#   'definition': 'Mother Christmas commonly known Mrs Claus outside United Kingdom \xa0 The wife Father Christmas displayed older woman  '},
#  'U+1F935': {'name': 'man in tuxedo',
#   'keywords': ['tuxedo', 'man', 'groom'],
#   'definition': 'A man dressed formal occassion wearing tuxedo This emoji gender pair bride emoji Man Tuxedo app'},
#  'U+1F934': {'name': 'prince',
#   'keywords': ['prince'],
#   'definition': 'Male royalty intended gender pair princess emoji Shown man crown Prince approved Unicode 9.0 2'},
#  'U+1F933': {'name': 'selfie',
#   'keywords': ['selfie', 'phone', 'camera'],
#   'definition': 'A camera usually mobile \xa0 phone camera held photo person holding May represented outstretched hand ph'},
#  'U+1F3CC U+1F3FC U+200D U+2642 U+FE0F': {'name': 'man golfing: medium-light skin tone',
#   'keywords': ['medium-light skin tone', 'golf', 'man'],
#   'definition': 'The Man Golfing Type-3 emoji sequence Golfer Emoji Modifier Fitzpatrick Type-3 Male Sign Variation Selector-16  '},
#  'U+1F930': {'name': 'pregnant woman',
#   'keywords': ['woman', 'pregnant'],
#   'definition': 'A pregnant woman intended complete family emoji \xa0 set Pregnant Woman approved Unicode 9.0 2016 added Emoji 3'},
#  'U+1F473 U+200D U+2640 U+FE0F': {'name': 'woman wearing turban',
#   'keywords': ['turban', 'woman'],
#   'definition': 'The female version \xa0 Man Wearing Turban emoji The Woman Wearing Turban emoji sequence Man With Turban Female Sign'},
#  'U+1F645 U+1F3FF U+200D U+2642 U+FE0F': {'name': 'man gesturing NO: dark skin tone',
#   'keywords': ['dark skin tone',
#    'hand',
#    'forbidden',
#    'gesture',
#    'prohibited',
#    'no',
#    'man'],
#   'definition': 'The Man Gesturing Not OK Type-6 emoji sequence Face With No Good Gesture Emoji Modifier Fitzpatrick Type-6 Male Sign  '},
#  'U+1F482 U+1F3FF U+200D U+2642 U+FE0F': {'name': 'man guard: dark skin tone',
#   'keywords': ['dark skin tone', 'guard', 'man'],
#   'definition': 'The Male Guard Type-6 emoji sequence Guardsman Emoji Modifier Fitzpatrick Type-6 Male Sign Variation Selector-1'},
#  'U+1F927': {'name': 'sneezing face',
#   'keywords': ['sneeze', 'gesundheit', 'face'],
#   'definition': 'A face displayed sneezing tissue blowing closed eyes Sneezing Face approved Unicode 9.0 2016  '},
#  'U+1F926': {'name': 'person facepalming',
#   'keywords': ['exasperation', 'disbelief', 'face', 'palm'],
#   'definition': 'A hand shown pressing head person commonly written \xa0 facepalm Used display \xa0 frustration embarrassment inepti'},
#  'U+1F925': {'name': 'lying face',
#   'keywords': ['lie', 'face', 'pinocchio'],
#   'definition': 'A person long nose indicate telling lie Lying Face approved Unicode 9.0 2016 added Emoji  '},
#  'U+1F924': {'name': 'drooling face',
#   'keywords': ['drooling', 'face'],
#   'definition': 'A face shown drool dripping mouth May display \xa0 desire person object concept Not co'},
#  'U+1F923': {'name': 'rolling on the floor laughing',
#   'keywords': ['laugh', 'rolling', 'floor', 'face'],
#   'definition': 'A character lying floor extreme laughter Face laughing possibly hand hitting floor \xa0 An emoji ve'},
#  'U+1F922': {'name': 'nauseated face',
#   'keywords': ['nauseated', 'face', 'vomit'],
#   'definition': 'A green face shown pursed lipsed \xa0 vomit Used literally sickness display \xa0 disgust Differs  '},
#  'U+1F3C3 U+200D U+2642 U+FE0F': {'name': 'man running',
#   'keywords': ['racing', 'running', 'marathon', 'man'],
#   'definition': 'The male version \xa0 Runner emoji \xa0 Currently identical appearance non gendered base emoji The Man Running emoji sequen'},
#  'U+1F921': {'name': 'clown face',
#   'keywords': ['face', 'clown'],
#   'definition': 'A face distinctively colored face makeup intended entertain children physical comedy May juggle create \xa0  balloon anima'},
#  'U+1F920': {'name': 'cowboy hat face',
#   'keywords': ['cowgirl', 'hat', 'face', 'cowboy'],
#   'definition': 'A face displayed wearing wide brimmed cowboy hat Shown yellow smiley non human appearance Cowboy Hat Face approved par'},
#  'U+1F938 U+1F3FC U+200D U+2642 U+FE0F': {'name': 'man cartwheeling: medium-light skin tone',
#   'keywords': ['gymnastics', 'medium-light skin tone', 'cartwheel', 'man'],
#   'definition': 'The Man Doing Cartwheel Type-3 emoji sequence Person Doing Cartwheel Emoji Modifier Fitzpatrick Type-3 Male Sign  '},
#  'U+1F91E': {'name': 'crossed fingers',
#   'keywords': ['luck', 'hand', 'finger', 'cross'],
#   'definition': 'A \xa0 fingers crossed emoji \xa0 displays \xa0 \xa0 index finger crossed \xa0 middle second \xa0 finger Commonly gesture indicati'},
#  'U+1F3CC U+FE0F U+200D U+2642 U+FE0F': {'name': 'man golfing',
#   'keywords': ['golf', 'man'],
#   'definition': 'The male version \xa0 Golfer emoji Currently identical appearance non gendered base emoji The Man Golfing emoji sequen'},
#  'U+1F91D': {'name': 'handshake',
#   'keywords': ['hand', 'shake', 'agreement', 'meeting', 'handshake'],
#   'definition': 'Two hands performing handshake gesture indicating \xa0 cordial greeting friends associates Handshake approved Uni'},
#  'U+1F91C': {'name': 'right-facing fist',
#   'keywords': ['fist', 'rightwards'],
#   'definition': 'A fist pointing right conjunction \xa0 left facing fist \xa0 complete \xa0 fist bump \xa0 gesture Right facing Fist app'},
#  'U+1F91B': {'name': 'left-facing fist',
#   'keywords': ['leftwards', 'fist'],
#   'definition': 'A fist pointing left conjunction right facing fist complete fist bump gesture Left facing Fist appr'},
#  'U+1F91A': {'name': 'raised back of hand',
#   'keywords': ['backhand', 'raised'],
#   'definition': 'A \xa0 raised hand showing reverse palm \xa0 May paired forward facing raised hand emoji Raised Back Hand approv'},
#  'U+1F468 U+1F3FD U+200D U+1F3ED': {'name': 'man factory worker: medium skin tone',
#   'keywords': ['industrial',
#    'factory',
#    'assembly',
#    'worker',
#    'medium skin tone',
#    'man'],
#   'definition': 'The Male Factory Worker Type-4 emoji sequence Man Emoji Modifier Fitzpatrick Type-4 Factory emojis These com'},
#  'U+1F486 U+200D U+2642 U+FE0F': {'name': 'man getting massage',
#   'keywords': ['face', 'massage', 'man'],
#   'definition': 'The male version \xa0 Face Massage emoji The Man Getting Massage emoji sequence Face Massage Male Sign Variati'},
#  'U+1F468 U+1F3FD U+200D U+1F3EB': {'name': 'man teacher: medium skin tone',
#   'keywords': ['instructor',
#    'professor',
#    'teacher',
#    'medium skin tone',
#    'man'],
#   'definition': 'The Male Teacher Type-4 emoji sequence Man Emoji Modifier Fitzpatrick Type-4 School emojis These combined'},
#  'U+1F3C3 U+1F3FE U+200D U+2642 U+FE0F': {'name': 'man running: medium-dark skin tone',
#   'keywords': ['racing',
#    'running',
#    'medium-dark skin tone',
#    'marathon',
#    'man'],
#   'definition': 'The Man Running Type-5 emoji sequence Runner Emoji Modifier Fitzpatrick Type-5 Male Sign Variation Selector-16  '},
#  'U+1F919': {'name': 'call me hand',
#   'keywords': ['hand', 'call'],
#   'definition': 'A hand thumb \xa0 little pinky finger extended making traditional \xa0 phone like shape \xa0 May conjunction face sugge'},
#  'U+1F918': {'name': 'sign of the horns',
#   'keywords': ['hand', 'horns', 'finger', 'rock-on'],
#   'definition': 'A rock \xa0 hand gesture raising pinky index fingers hand variety \xa0 meanings Sign Horns approved  '},
#  'U+1F917': {'name': 'hugging face',
#   'keywords': ['hug', 'face', 'hugging'],
#   'definition': 'A face displayed open hands gesture offering hug Hugging Face approved Unicode 8.0 2015 added Emoji 1.0'},
#  'U+1F916': {'name': 'robot face',
#   'keywords': ['monster', 'face', 'robot'],
#   'definition': 'A robot face showing metallic head \xa0 eyes grill like mouth similar grimace Was available Gmail prior inc'},
#  'U+1F915': {'name': 'face with head-bandage',
#   'keywords': ['hurt', 'bandage', 'face', 'injury'],
#   'definition': 'A face showing bandage wrapped head Used injured Differs face thermometer'},
#  'U+1F914': {'name': 'thinking face',
#   'keywords': ['thinking', 'face'],
#   'definition': 'A face shown single finger thumb resting chin glancing upward Used indicate thinking deep thought Can paired  '},
#  'U+1F913': {'name': 'nerd face',
#   'keywords': ['face', 'geek', 'nerd'],
#   'definition': 'A sterotypically “ nerd like ” face glasses buck teeth Nerd Face approved Unicode 8.0 2015 added Emoji 1.0'},
#  'U+1F912': {'name': 'face with thermometer',
#   'keywords': ['thermometer', 'ill', 'sick', 'face'],
#   'definition': 'A face shown thermometer presumed \xa0 feeling sick May patient hospital common cold Differs  '},
#  'U+1F911': {'name': 'money-mouth face',
#   'keywords': ['mouth', 'money', 'face'],
#   'definition': 'A face \xa0 bank note showing instead tongue \xa0 dollar signs instead eyes Indicates love money feeling wealth Mo'},
#  'U+1F910': {'name': 'zipper-mouth face',
#   'keywords': ['zipper', 'mouth', 'face'],
#   'definition': 'A face zipper displayed instead mouth Used convey secret discuss certain matter aka “ m'},
#  'U+1F471 U+1F3FC U+200D U+2640 U+FE0F': {'name': 'blond-haired woman: medium-light skin tone',
#   'keywords': ['medium-light skin tone', 'woman', 'blonde'],
#   'definition': 'The Blonde Woman Type-3 emoji sequence Person With Blond Hair Emoji Modifier Fitzpatrick Type-3 Female Sign Var'},
#  'U+1F469 U+1F3FD U+200D U+2695 U+FE0F': {'name': 'woman health worker: medium skin tone',
#   'keywords': ['doctor',
#    'nurse',
#    'healthcare',
#    'woman',
#    'therapist',
#    'medium skin tone'],
#   'definition': 'The Female Health Worker Type-4 emoji sequence Woman Emoji Modifier Fitzpatrick Type-4 Staff Of Aesculapius Var'},
#  'U+1F93D U+1F3FE U+200D U+2640 U+FE0F': {'name': 'woman playing water polo: medium-dark skin tone',
#   'keywords': ['medium-dark skin tone', 'woman', 'water polo'],
#   'definition': 'The Woman Playing Water Polo Type-5 emoji sequence Water Polo Emoji Modifier Fitzpatrick Type-5 Female Sign Var'},
#  'U+1F6B6 U+1F3FB U+200D U+2642 U+FE0F': {'name': 'man walking: light skin tone',
#   'keywords': ['walk', 'light skin tone', 'hike', 'man'],
#   'definition': 'The Man Walking Type-1 2 emoji sequence Pedestrian Emoji Modifier Fitzpatrick Type-1 2 Male Sign Variation Sele'},
#  'U+1F646 U+1F3FF U+200D U+2640 U+FE0F': {'name': 'woman gesturing OK: dark skin tone',
#   'keywords': ['dark skin tone', 'hand', 'ok', 'gesture', 'woman'],
#   'definition': 'The Woman Gesturing OK Type-6 emoji sequence Face With OK Gesture Emoji Modifier Fitzpatrick Type-6 Female Sign'},
#  'U+1F939 U+1F3FC U+200D U+2640 U+FE0F': {'name': 'woman juggling: medium-light skin tone',
#   'keywords': ['multitask', 'juggling', 'medium-light skin tone', 'woman'],
#   'definition': 'The Woman Juggling Type-3 emoji sequence Juggling Emoji Modifier Fitzpatrick Type-3 Female Sign Variation Selec'},
#  'U+1F3C4 U+1F3FE U+200D U+2640 U+FE0F': {'name': 'woman surfing: medium-dark skin tone',
#   'keywords': ['medium-dark skin tone', 'woman', 'surfing'],
#   'definition': 'The Woman Surfing Type-5 emoji sequence Surfer Emoji Modifier Fitzpatrick Type-5 Female Sign Variation Selector'},
#  'U+1F3C2 U+1F3FF': {'name': 'snowboarder: dark skin tone',
#   'keywords': ['ski', 'dark skin tone', 'snowboard', 'snow'],
#   'definition': 'This version Snowboarder emoji Dark Skin Tone applied displayed Black Skin Tone supported platforms  '},
#  'U+1F3C2 U+1F3FE': {'name': 'snowboarder: medium-dark skin tone',
#   'keywords': ['ski', 'snowboard', 'medium-dark skin tone', 'snow'],
#   'definition': 'This version Snowboarder emoji Medium dark Skin Tone applied displayed Dark Brown Skin Tone supported'},
#  'U+1F3C2 U+1F3FD': {'name': 'snowboarder: medium skin tone',
#   'keywords': ['ski', 'snowboard', 'snow', 'medium skin tone'],
#   'definition': 'This version Snowboarder emoji Medium Skin Tone applied displayed Moderate Brown Skin Tone supported  '},
#  'U+1F3C2 U+1F3FC': {'name': 'snowboarder: medium-light skin tone',
#   'keywords': ['ski', 'snowboard', 'medium-light skin tone', 'snow'],
#   'definition': 'This version Snowboarder emoji Medium light Skin Tone applied displayed Cream White Skin Tone support'},
#  'U+1F3C2 U+1F3FB': {'name': 'snowboarder: light skin tone',
#   'keywords': ['ski', 'light skin tone', 'snowboard', 'snow'],
#   'definition': 'This version Snowboarder emoji Light Skin Tone applied displayed Pale Skin Tone supported platforms  '},
#  'U+1F468 U+1F3FD U+200D U+1F3A8': {'name': 'man artist: medium skin tone',
#   'keywords': ['artist', 'palette', 'medium skin tone', 'man'],
#   'definition': 'The Male Artist Type-4 emoji sequence Man Emoji Modifier Fitzpatrick Type-4 Artist Palette emojis These comb'},
#  'U+24C2': {'name': 'circled M',
#   'keywords': ['m', 'circle'],
#   'definition': 'The letter M circle commonly identify Metro subway underground train station city area Circled M approved'},
#  'U+1F468 U+1F3FD U+200D U+1F3A4': {'name': 'man singer: medium skin tone',
#   'keywords': ['entertainer',
#    'singer',
#    'actor',
#    'star',
#    'rock',
#    'medium skin tone',
#    'man'],
#   'definition': 'The Male Singer Type-4 emoji sequence Man Emoji Modifier Fitzpatrick Type-4 Microphone emojis These combined'},
#  'U+1F477 U+1F3FF U+200D U+2640 U+FE0F': {'name': 'woman construction worker: dark skin tone',
#   'keywords': ['dark skin tone', 'woman', 'worker', 'construction'],
#   'definition': 'The Female Construction Worker Type-6 emoji sequence Construction Worker Emoji Modifier Fitzpatrick Type-6 Female Sig'},
#  'U+1F469 U+1F3FD U+200D U+2696 U+FE0F': {'name': 'woman judge: medium skin tone',
#   'keywords': ['judge', 'woman', 'scales', 'medium skin tone'],
#   'definition': 'The Female Judge Type-4 emoji sequence Woman Emoji Modifier Fitzpatrick Type-4 Scales Variation Selector-16 emo'},
#  'U+1F486 U+1F3FC U+200D U+2642 U+FE0F': {'name': 'man getting massage: medium-light skin tone',
#   'keywords': ['medium-light skin tone', 'face', 'massage', 'man'],
#   'definition': 'The Man Getting Face Massage Type-3 emoji sequence Face Massage Emoji Modifier Fitzpatrick Type-3 Male Sign Var'},
#  'U+1F3CA U+1F3FF U+200D U+2640 U+FE0F': {'name': 'woman swimming: dark skin tone',
#   'keywords': ['dark skin tone', 'swim', 'woman'],
#   'definition': 'The Woman Swimming Type-6 emoji sequence Swimmer Emoji Modifier Fitzpatrick Type-6 Female Sign Variation Select'},
#  'U+1F937 U+200D U+2640 U+FE0F': {'name': 'woman shrugging',
#   'keywords': ['woman', 'indifference', 'shrug', 'ignorance', 'doubt'],
#   'definition': 'The Woman Shrugging emoji sequence Shrug Female Sign Variation Selector-16 emojis These combined zero w'},
#  'U+1F575 U+1F3FF U+200D U+2642 U+FE0F': {'name': 'man detective: dark skin tone',
#   'keywords': ['dark skin tone', 'sleuth', 'spy', 'detective', 'man'],
#   'definition': 'The Male Sleuth Type-6 emoji sequence Sleuth Spy Emoji Modifier Fitzpatrick Type-6 Male Sign Variation Selec'},
#  'U+1F473 U+200D U+2642 U+FE0F': {'name': 'man wearing turban',
#   'keywords': ['turban', 'man'],
#   'definition': 'The male \xa0 version \xa0 Woman Wearing Turban \xa0 emoji The Man Wearing Turban emoji sequence Man With Turban Male Sign  '},
#  'U+1F468 U+200D U+1F469 U+200D U+1F467': {'name': 'family: man, woman, girl',
#   'keywords': ['family', 'woman', 'girl', 'man'],
#   'definition': 'A family \xa0 father mother \xa0 daughter The Family Man Woman Girl emoji sequence Man Woman Girl emoji'},
#  'U+1F468 U+200D U+1F469 U+200D U+1F466': {'name': 'family: man, woman, boy',
#   'keywords': ['family', 'boy', 'woman', 'man'],
#   'definition': 'The Family Man Woman Boy emoji sequence Man Woman Boy emojis These combined zero width joiner betw'},
#  'U+1F487 U+1F3FC U+200D U+2640 U+FE0F': {'name': 'woman getting haircut: medium-light skin tone',
#   'keywords': ['medium-light skin tone', 'woman', 'haircut'],
#   'definition': 'The Woman Getting Haircut Type-3 emoji sequence Haircut Emoji Modifier Fitzpatrick Type-3 Female Sign Variation'},
#  'U+1F46E U+1F3FF': {'name': 'police officer: dark skin tone',
#   'keywords': ['dark skin tone', 'officer', 'police', 'cop'],
#   'definition': 'This version Police Officer emoji Dark Skin Tone applied displayed Black Skin Tone supported platform'},
#  'U+1F46E U+1F3FE': {'name': 'police officer: medium-dark skin tone',
#   'keywords': ['officer', 'medium-dark skin tone', 'police', 'cop'],
#   'definition': 'This version Police Officer emoji Medium dark Skin Tone applied displayed Dark Brown Skin Tone suppor'},
#  'U+1F46E U+1F3FD': {'name': 'police officer: medium skin tone',
#   'keywords': ['officer', 'police', 'medium skin tone', 'cop'],
#   'definition': 'This version Police Officer emoji Medium Skin Tone applied displayed Moderate Brown Skin Tone support'},
#  'U+1F46E U+1F3FC': {'name': 'police officer: medium-light skin tone',
#   'keywords': ['officer', 'medium-light skin tone', 'police', 'cop'],
#   'definition': 'This version Police Officer emoji Medium light Skin Tone applied displayed Cream White Skin Tone supp'},
#  'U+1F46E U+1F3FB': {'name': 'police officer: light skin tone',
#   'keywords': ['light skin tone', 'officer', 'police', 'cop'],
#   'definition': 'This version Police Officer emoji Light Skin Tone applied displayed Pale Skin Tone supported platform'},
#  'U+1F468 U+200D U+1F4BC': {'name': 'man office worker',
#   'keywords': ['manager',
#    'business',
#    'office',
#    'architect',
#    'white-collar',
#    'man'],
#   'definition': 'The Man Office Worker emoji sequence Man Briefcase emojis These combined zero width joiner c'},
#  'U+1F468 U+200D U+1F4BB': {'name': 'man technologist',
#   'keywords': ['coder',
#    'developer',
#    'software',
#    'technologist',
#    'inventor',
#    'man'],
#   'definition': 'A man computer screen working field technology See \xa0 \xa0 Female Technologist The Man Technologist emoji sequ'},
#  'U+1F3C3 U+1F3FF': {'name': 'person running: dark skin tone',
#   'keywords': ['dark skin tone', 'running', 'marathon'],
#   'definition': 'This version Person Running emoji Dark Skin Tone applied displayed Black Skin Tone supported platform'},
#  'U+1F3C3 U+1F3FE': {'name': 'person running: medium-dark skin tone',
#   'keywords': ['running', 'medium-dark skin tone', 'marathon'],
#   'definition': 'This version Person Running emoji Medium dark Skin Tone applied displayed Dark Brown Skin Tone suppor'},
#  'U+1F3C3 U+1F3FD': {'name': 'person running: medium skin tone',
#   'keywords': ['running', 'marathon', 'medium skin tone'],
#   'definition': 'This version Person Running emoji Medium Skin Tone applied displayed Moderate Brown Skin Tone support'},
#  'U+1F6B4 U+1F3FE U+200D U+2640 U+FE0F': {'name': 'woman biking: medium-dark skin tone',
#   'keywords': ['bicycle',
#    'cyclist',
#    'medium-dark skin tone',
#    'woman',
#    'biking'],
#   'definition': 'The Woman Biking Type-5 emoji sequence Bicyclist Emoji Modifier Fitzpatrick Type-5 Female Sign Variation Select'},
#  'U+1F3C3 U+1F3FC': {'name': 'person running: medium-light skin tone',
#   'keywords': ['running', 'medium-light skin tone', 'marathon'],
#   'definition': 'This version Person Running emoji Medium light Skin Tone applied displayed Cream White Skin Tone supp'},
#  'U+1F3C3 U+1F3FB': {'name': 'person running: light skin tone',
#   'keywords': ['running', 'light skin tone', 'marathon'],
#   'definition': 'This version Person Running emoji Light Skin Tone applied displayed Pale Skin Tone supported platform'},
#  'U+1F468 U+1F3FD U+200D U+2708 U+FE0F': {'name': 'man pilot: medium skin tone',
#   'keywords': ['plane', 'pilot', 'medium skin tone', 'man'],
#   'definition': 'The Male Pilot Type-4 emoji sequence Man Emoji Modifier Fitzpatrick Type-4 Airplane Variation Selector-16 emoji'},
#  'U+1F64D U+1F3FB U+200D U+2642 U+FE0F': {'name': 'man frowning: light skin tone',
#   'keywords': ['light skin tone', 'frowning', 'gesture', 'man'],
#   'definition': 'The Man Frowning Type-1 2 emoji sequence Person Frowning Emoji Modifier Fitzpatrick Type-1 2 Male Sign Variatio'},
#  'U+26F9 U+1F3FF U+200D U+2640 U+FE0F': {'name': 'woman bouncing ball: dark skin tone',
#   'keywords': ['dark skin tone', 'woman', 'ball'],
#   'definition': 'The Woman With Ball Type-6 emoji sequence Person With Ball Emoji Modifier Fitzpatrick Type-6 Female Sign Variati'},
#  'U+1F469 U+1F3FE U+200D U+1F4BC': {'name': 'woman office worker: medium-dark skin tone',
#   'keywords': ['manager',
#    'business',
#    'office',
#    'medium-dark skin tone',
#    'woman',
#    'architect',
#    'white-collar'],
#   'definition': 'The Female Office Worker Type-5 emoji sequence Woman Emoji Modifier Fitzpatrick Type-5 Briefcase emojis These ar'},
#  'U+1F469 U+1F3FE U+200D U+1F4BB': {'name': 'woman technologist: medium-dark skin tone',
#   'keywords': ['coder',
#    'developer',
#    'software',
#    'medium-dark skin tone',
#    'woman',
#    'technologist',
#    'inventor'],
#   'definition': 'The Female Technologist Type-5 emoji sequence Woman Emoji Modifier Fitzpatrick Type-5 Personal Computer emojis T'},
#  'U+1F469 U+200D U+1F3ED': {'name': 'woman factory worker',
#   'keywords': ['industrial', 'factory', 'assembly', 'woman', 'worker'],
#   'definition': 'The Woman Factory Worker emoji sequence Woman Factory emojis These combined zero width joiner eac'},
#  'U+1F93D U+1F3FE U+200D U+2642 U+FE0F': {'name': 'man playing water polo: medium-dark skin tone',
#   'keywords': ['medium-dark skin tone', 'water polo', 'man'],
#   'definition': 'The Man Playing Water Polo Type-5 emoji sequence Water Polo Emoji Modifier Fitzpatrick Type-5 Male Sign Variati'},
#  'U+1F469 U+200D U+1F3EB': {'name': 'woman teacher',
#   'keywords': ['instructor', 'professor', 'woman', 'teacher'],
#   'definition': 'A woman standing chalkboard aka blackboard intention teaching class See \xa0 \xa0 Male Teacher The Woman Te'},
#  'U+1F646 U+1F3FF U+200D U+2642 U+FE0F': {'name': 'man gesturing OK: dark skin tone',
#   'keywords': ['dark skin tone', 'hand', 'ok', 'gesture', 'man'],
#   'definition': 'The Man Gesturing OK Type-6 emoji sequence Face With OK Gesture Emoji Modifier Fitzpatrick Type-6 Male Sign Var'},
#  'U+1F469 U+1F3FF U+200D U+1F3ED': {'name': 'woman factory worker: dark skin tone',
#   'keywords': ['industrial',
#    'dark skin tone',
#    'factory',
#    'assembly',
#    'woman',
#    'worker'],
#   'definition': 'The Female Factory Worker Type-6 emoji sequence Woman Emoji Modifier Fitzpatrick Type-6 Factory emojis These'},
#  'U+1F469 U+1F3FF U+200D U+1F3EB': {'name': 'woman teacher: dark skin tone',
#   'keywords': ['instructor',
#    'dark skin tone',
#    'professor',
#    'woman',
#    'teacher'],
#   'definition': 'The Female Teacher Type-6 emoji sequence Woman Emoji Modifier Fitzpatrick Type-6 School emojis These combine'},
#  'U+1F939 U+1F3FC U+200D U+2642 U+FE0F': {'name': 'man juggling: medium-light skin tone',
#   'keywords': ['multitask', 'juggling', 'medium-light skin tone', 'man'],
#   'definition': 'The Man Juggling Type-3 emoji sequence Juggling Emoji Modifier Fitzpatrick Type-3 Male Sign Variation Selector-'},
#  'U+1F64E U+1F3FB U+200D U+2640 U+FE0F': {'name': 'woman pouting: light skin tone',
#   'keywords': ['light skin tone', 'pouting', 'gesture', 'woman'],
#   'definition': 'The Woman Pouting Type-1 2 emoji sequence Person With Pouting Face Emoji Modifier Fitzpatrick Type-1 2 Female Sign'},
#  'U+1F93E U+1F3FE U+200D U+2640 U+FE0F': {'name': 'woman playing handball: medium-dark skin tone',
#   'keywords': ['medium-dark skin tone', 'woman', 'handball'],
#   'definition': 'The Woman Playing Handball Type-5 emoji sequence Handball Emoji Modifier Fitzpatrick Type-5 Female Sign Variati'},
#  'U+1F468 U+1F3FD U+200D U+1F393': {'name': 'man student: medium skin tone',
#   'keywords': ['graduate', 'student', 'medium skin tone', 'man'],
#   'definition': 'The Male Student Type-4 emoji sequence Man Emoji Modifier Fitzpatrick Type-4 Graduation Cap emojis These com'},
#  'U+1F468 U+1F3FB U+200D U+2695 U+FE0F': {'name': 'man health worker: light skin tone',
#   'keywords': ['light skin tone',
#    'doctor',
#    'nurse',
#    'healthcare',
#    'therapist',
#    'man'],
#   'definition': 'The Male Health Worker Type-1 2 emoji sequence Man Emoji Modifier Fitzpatrick Type-1 2 Staff Of Aesculapius Var'},
#  'U+1F3C4 U+1F3FF': {'name': 'person surfing: dark skin tone',
#   'keywords': ['dark skin tone', 'surfing'],
#   'definition': 'This version Person Surfing emoji Dark Skin Tone applied displayed Black Skin Tone supported platform'},
#  'U+1F3C4 U+1F3FE': {'name': 'person surfing: medium-dark skin tone',
#   'keywords': ['medium-dark skin tone', 'surfing'],
#   'definition': 'This version Person Surfing emoji Medium dark Skin Tone applied displayed Dark Brown Skin Tone suppor'},
#  'U+1F3C4 U+1F3FD': {'name': 'person surfing: medium skin tone',
#   'keywords': ['surfing', 'medium skin tone'],
#   'definition': 'This version Person Surfing emoji Medium Skin Tone applied displayed Moderate Brown Skin Tone support'},
#  'U+1F3C4 U+1F3FC': {'name': 'person surfing: medium-light skin tone',
#   'keywords': ['medium-light skin tone', 'surfing'],
#   'definition': 'This version Person Surfing emoji Medium light Skin Tone applied displayed Cream White Skin Tone supp'},
#  'U+1F3C4 U+1F3FB': {'name': 'person surfing: light skin tone',
#   'keywords': ['light skin tone', 'surfing'],
#   'definition': 'This version Person Surfing emoji Light Skin Tone applied displayed Pale Skin Tone supported platform'},
#  'U+1F645 U+1F3FD U+200D U+2640 U+FE0F': {'name': 'woman gesturing NO: medium skin tone',
#   'keywords': ['hand',
#    'forbidden',
#    'gesture',
#    'woman',
#    'prohibited',
#    'no',
#    'medium skin tone'],
#   'definition': 'The Woman Gesturing Not OK Type-4 emoji sequence Face With No Good Gesture Emoji Modifier Fitzpatrick Type-4 Female S'},
#  'U+1F468 U+200D U+2764 U+FE0F U+200D U+1F48B U+200D U+1F468': {'name': 'kiss: man, man',
#   'keywords': ['couple', 'man'],
#   'definition': 'Two men displayed kissing gesturing kiss \xa0 At small sizes difficult discern women kissing'},
#  'U+1F482 U+1F3FD U+200D U+2640 U+FE0F': {'name': 'woman guard: medium skin tone',
#   'keywords': ['woman', 'guard', 'medium skin tone'],
#   'definition': 'The Female Guard Type-4 emoji sequence Guardsman Emoji Modifier Fitzpatrick Type-4 Female Sign Variation Select'},
#  'U+1F477 U+1F3FF U+200D U+2642 U+FE0F': {'name': 'man construction worker: dark skin tone',
#   'keywords': ['dark skin tone', 'worker', 'man', 'construction'],
#   'definition': 'The Male Construction Worker Type-6 emoji sequence Construction Worker Emoji Modifier Fitzpatrick Type-6 Male Sign'},
#  'U+1F469 U+200D U+2695 U+FE0F': {'name': 'woman health worker',
#   'keywords': ['doctor', 'nurse', 'healthcare', 'woman', 'therapist'],
#   'definition': 'A woman working field health care This represent doctor nurse pharmacist See Male Health Worke'},
#  'U+1F469 U+200D U+1F3A8': {'name': 'woman artist',
#   'keywords': ['artist', 'palette', 'woman'],
#   'definition': 'The Woman Artist emoji sequence Woman Artist Palette emojis These combined zero width joiner'},
#  'U+1F441 U+FE0F U+200D U+1F5E8 U+FE0F': {'name': 'eye in speech bubble',
#   'keywords': ['eye', 'witness', 'speech bubble'],
#   'definition': 'A speech bubble showing eye inside When text speech Apple platforms emoji read aloud Eye speech bubble repr'},
#  'U+1F469 U+200D U+1F3A4': {'name': 'woman singer',
#   'keywords': ['entertainer', 'singer', 'actor', 'woman', 'star', 'rock'],
#   'definition': 'The Woman Singer emoji sequence Woman Microphone emojis These combined zero width joiner cha'},
#  'U+1F468 U+1F3FD U+200D U+1F373': {'name': 'man cook: medium skin tone',
#   'keywords': ['cook', 'chef', 'medium skin tone', 'man'],
#   'definition': 'The Male Cook Type-4 emoji sequence Man Emoji Modifier Fitzpatrick Type-4 Cooking emojis These combined usin'},
#  'U+1F3C3 U+1F3FC U+200D U+2640 U+FE0F': {'name': 'woman running: medium-light skin tone',
#   'keywords': ['racing',
#    'running',
#    'medium-light skin tone',
#    'woman',
#    'marathon'],
#   'definition': 'The Woman Running Type-3 emoji sequence Runner Emoji Modifier Fitzpatrick Type-3 Female Sign Variation Selector'},
#  'U+1F251': {'name': 'Japanese “acceptable” button',
#   'keywords': ['japanese', '?', '“acceptable”', 'ideograph'],
#   'definition': 'Japanese “ acceptable ” Button approved Unicode 6.0 2010 “ Circled Ideograph Accept ” added Emoji 1.0'},
#  'U+1F250': {'name': 'Japanese “bargain” button',
# ...
#   'keywords': ['eye', 'cat', 'smile', 'grin', 'face'],
#   'definition': 'The cat variant \xa0 Grinning Face Emoji Grinning Cat Face With Smiling Eyes approved Unicode 6.0 2010 added Emo'},
#  'U+1F637': {'name': 'face with medical mask',
#   'keywords': ['medicine', 'mask', 'cold', 'doctor', 'sick', 'face'],
#   'definition': 'A person surgical mask face generally \xa0 hospital \xa0 setting working dangerous fumes Also \xa0 seen \xa0 public'},
#  'U+1F636': {'name': 'face without mouth',
#   'keywords': ['silent', 'mouth', 'quiet', 'face'],
#   'definition': 'This emoji eyes mouth Represents silence emoji silent Imagine things mouth Fa'},
#  'U+1F635': {'name': 'dizzy face',
#   'keywords': ['face', 'dizzy'],
#   'definition': 'A dizzy face looking sick confused spun circles times Difficult distinguish \xa0 Astonished Face \xa0'},
#  'U+1F634': {'name': 'sleeping face',
#   'keywords': ['zzz', 'sleep', 'face'],
#   'definition': 'Face eyes closed sleep symbol – Zzz – head Generally instead \xa0 Sleepy Face Emoji \xa0 indicate sleeping'},
#  'U+1F633': {'name': 'flushed face',
#   'keywords': ['flushed', 'face', 'dazed'],
#   'definition': 'An embarrassed face \xa0 flushed red cheeks \xa0 This face \xa0 blushing mistake embarrassing situation In Apple artwork \xa0 t'},
#  'U+1F632': {'name': 'astonished face',
#   'keywords': ['totally', 'shocked', 'astonished', 'face'],
#   'definition': 'An astonished face wide open mouth gasping shock surprise The Google artwork emoji looks slightly inebriated  '},
#  'U+1F631': {'name': 'face screaming in fear',
#   'keywords': ['scared', 'munch', 'fearful', 'scream', 'fear', 'face'],
#   'definition': 'A screaming face hands holding jaw cheeks fear Wide eyes shown open mouth The Samsung version emoj'},
#  'U+1F630': {'name': 'face with open mouth & cold sweat',
#   'keywords': ['blue', 'cold', 'mouth', 'open', 'sweat', 'rushed', 'face'],
#   'definition': 'A look concern blue forehead sweat dripping cheek The exception emoji Windows version appeare'},
#  'U+1F62F': {'name': 'hushed face',
#   'keywords': ['surprised', 'stunned', 'hushed', 'face'],
#   'definition': 'A face looks surprised hushed high eyebrows open mouth The appearance similar \xa0 Astonished face'},
#  'U+1F62E': {'name': 'face with open mouth',
#   'keywords': ['mouth', 'open', 'sympathy', 'face'],
#   'definition': 'A face mouth wide open generally \xa0 represent \xa0 element surprise Can \xa0 “ mock shock ” le'},
#  'U+1F62D': {'name': 'loudly crying face',
#   'keywords': ['sob', 'sad', 'face', 'cry', 'tear'],
#   'definition': 'A sad face tears streaming cheeks \xa0 This face \xa0 distraught inconsolable Not confused tears joy emoji  '},
#  'U+1F62C': {'name': 'grimacing face',
#   'keywords': ['grimace', 'face'],
#   'definition': 'A grimace emoji showing bared teeth usually mistake unfavorable situation arisen – aka “ eek ” \xa0 The appearance emo'},
#  'U+1F62B': {'name': 'tired face',
#   'keywords': ['tired', 'face'],
#   'definition': 'An exhausted looking face \xa0 open mouth tightly closed eyes \xa0 On platforms emoji similar appearance \xa0 Weary Fac'},
#  'U+1F62A': {'name': 'sleepy face',
#   'keywords': ['sleep', 'face'],
#   'definition': 'Not confused Sleeping Face Emoji sleepy face emoji features snot bubble coming nose This \xa0 anime'},
#  'U+1F647 U+1F3FD U+200D U+2642 U+FE0F': {'name': 'man bowing: medium skin tone',
#   'keywords': ['favor',
#    'apology',
#    'gesture',
#    'sorry',
#    'bowing',
#    'medium skin tone',
#    'man'],
#   'definition': 'The Man Bowing Deeply Type-4 emoji sequence Person Bowing Deeply Emoji Modifier Fitzpatrick Type-4 Male Sign Va'},
#  'U+1F468 U+1F3FE U+200D U+1F680': {'name': 'man astronaut: medium-dark skin tone',
#   'keywords': ['rocket', 'medium-dark skin tone', 'astronaut', 'man'],
#   'definition': 'The Male Astronaut Type-5 emoji sequence Man Emoji Modifier Fitzpatrick Type-5 Rocket emojis These combined  '},
#  'U+1F629': {'name': 'weary face',
#   'keywords': ['tired', 'face', 'weary'],
#   'definition': 'A distraught looking emoji open mouth crescent shaped eyes Appears given Very similar appearance Tired F'},
#  'U+1F628': {'name': 'fearful face',
#   'keywords': ['scared', 'fearful', 'fear', 'face'],
#   'definition': 'A face wide open eyes raised eyebrows Appears shocked scary event Fearful Face approved Unicode 6.0  '},
#  'U+1F627': {'name': 'anguished face',
#   'keywords': ['anguished', 'face'],
#   'definition': 'This \xa0 face \xa0 raised eyebrows open eyes open mouth \xa0 A mixture shock disappointment Anguished Face approved Unico'},
#  'U+1F626': {'name': 'frowning face with open mouth',
#   'keywords': ['mouth', 'open', 'face', 'frown'],
#   'definition': 'Face open eyes open mouth The Apple artwork emoji looks like person yawning Google Microsoft artwork \xa0 appear clos'},
#  'U+1F625': {'name': 'disappointed but relieved face',
#   'keywords': ['disappointed', 'whew', 'relieved', 'face'],
#   'definition': 'This face \xa0 sweat dripping brow stressful situation Not confused Crying Face emoji tear'},
#  'U+1F624': {'name': 'face with steam from nose',
#   'keywords': ['triumph', 'face', 'won'],
#   'definition': 'A face air coming nose proud disdainful way Commonly representing frustration situation'},
#  'U+1F623': {'name': 'persevering face',
#   'keywords': ['persevere', 'face'],
#   'definition': 'Face scrunched closed eyes frowning Used helplessness situation May verge tears Persevering Face w'},
#  'U+1F622': {'name': 'crying face',
#   'keywords': ['sad', 'face', 'cry', 'tear'],
#   'definition': 'A sad face single tear running eye cheek Hurt upset crying hysterically Some \xa0 versions emoji'},
#  'U+1F621': {'name': 'pouting face',
#   'keywords': ['rage', 'angry', 'pouting', 'face', 'red', 'mad'],
#   'definition': 'A pouting face outwardly showing \xa0 displeasure person situation Displayed furrowed brow platforms emoji com'},
#  'U+1F620': {'name': 'angry face',
#   'keywords': ['angry', 'face', 'mad'],
#   'definition': 'An angry looking face Has inward facing eyebrows frowning mouth Expresses anger grumpiness annoyance situation Angry Face'},
#  'U+1F61F': {'name': 'worried face',
#   'keywords': ['face', 'worried'],
#   'definition': 'Face sad mouth worried looking eyebrows Worried Face approved Unicode 6.1 2012 added Emoji 1.0 2015'},
#  'U+1F61E': {'name': 'disappointed face',
#   'keywords': ['disappointed', 'face'],
#   'definition': 'A sad face frowning mouth disappointed \xa0 eyes Not confused \xa0 pensive face \xa0 remorseful Disappointed Face'},
#  'U+1F61D': {'name': 'face with stuck-out tongue & closed eyes',
#   'keywords': ['horrible', 'eye', 'face', 'tongue', 'taste'],
#   'definition': 'Has eyes closed sticking tongue Face With Stuck Tongue Closed Eyes approved Unicode 6.0 2010 na'},
#  'U+1F61C': {'name': 'face with stuck-out tongue & winking eye',
#   'keywords': ['eye', 'wink', 'face', 'tongue', 'joke'],
#   'definition': 'A face showing stuck tongue winking time \xa0 Used attempt wacky zany joking Face With Stuck  '},
#  'U+1F61B': {'name': 'face with stuck-out tongue',
#   'keywords': ['face', 'tongue'],
#   'definition': 'A cheeky face sticking tongue \xa0 jest \xa0 Used way stating “ I kidding ” generally jovial Face With S'},
#  'U+1F61A': {'name': 'kissing face with closed eyes',
#   'keywords': ['kiss', 'eye', 'closed', 'face'],
#   'definition': 'A face pursed lips slightly blushing making kissing motion More intimate regular \xa0 kissing face emoji eyes b'},
#  'U+1F619': {'name': 'kissing face with smiling eyes',
#   'keywords': ['kiss', 'eye', 'smile', 'face'],
#   'definition': 'This emoji kissing looks like whistling emoji blowing air A bit ‘ innocent I pretending I anythin'},
#  'U+1F469 U+1F3FC U+200D U+2696 U+FE0F': {'name': 'woman judge: medium-light skin tone',
#   'keywords': ['judge', 'medium-light skin tone', 'woman', 'scales'],
#   'definition': 'The Female Judge Type-3 emoji sequence Woman Emoji Modifier Fitzpatrick Type-3 Scales Variation Selector-16 emo'},
#  'U+1F618': {'name': 'face blowing a kiss',
#   'keywords': ['kiss', 'face'],
#   'definition': 'An emoji face blowing \xa0 kiss \xa0 officially called “ Face Throwing A Kiss ” One eye open winking A heart shown leaving  '},
#  'U+1F617': {'name': 'kissing face',
#   'keywords': ['kiss', 'face'],
#   'definition': 'This emoji kissing looks like whistling emoji blowing air A bit ‘ innocent I pretending I anythin'},
#  'U+1F616': {'name': 'confounded face',
#   'keywords': ['face', 'confounded'],
#   'definition': 'On verge tears emoji tightly closed eyes quivering mouth Confounded Face approved Unicode 6.0 201'},
#  'U+1F615': {'name': 'confused face',
#   'keywords': ['confused', 'face'],
#   'definition': 'Part displeased unsure think This face \xa0 sad bit confused puzzled situation On spectrum disp'},
#  'U+1F614': {'name': 'pensive face',
#   'keywords': ['dejected', 'pensive', 'face'],
#   'definition': 'A pensive remorseful \xa0 face Saddened life Quietly considering things went wrong Pensive Face approved Unicode  '},
#  'U+1F613': {'name': 'face with cold sweat',
#   'keywords': ['cold', 'sweat', 'face'],
#   'definition': 'A face sad neutral mouth \xa0 single drop sweat Face With Cold Sweat approved Unicode 6.0 2010 added  '},
#  'U+1F612': {'name': 'unamused face',
#   'keywords': ['unhappy', 'unamused', 'face'],
#   'definition': 'This face amused This face sadness grumpy displeased look Used express dissatisfaction The eyes'},
#  'U+1F611': {'name': 'expressionless face',
#   'keywords': ['unexpressive', 'expressionless', 'inexpressive', 'face'],
#   'definition': 'A face narrow closed eyes straight mouth A deliberate display ‘ comment ’ opposed completely neutral face Express'},
#  'U+1F610': {'name': 'neutral face',
#   'keywords': ['deadpan', 'neutral', 'face'],
#   'definition': 'A face featuring straight closed mouth giving away particular emotion Neutral Face approved Unicode 6.0 20'},
#  'U+1F60F': {'name': 'smirking face',
#   'keywords': ['face', 'smirk'],
#   'definition': 'A sly smile sexual smug connotation Not confused unamused face similar eyes displea'},
#  'U+1F60E': {'name': 'smiling face with sunglasses',
#   'keywords': ['eyewear',
#    'smile',
#    'eye',
#    'sun',
#    'glasses',
#    'sunglasses',
#    'face',
#    'bright',
#    'cool'],
#   'definition': 'A face smiling wearing dark sunglasses \xa0 denote sense cool The nerd face emoji similar face \xa0 regular g'},
#  'U+1F469 U+1F3FC U+200D U+1F52C': {'name': 'woman scientist: medium-light skin tone',
#   'keywords': ['mathematician',
#    'engineer',
#    'medium-light skin tone',
#    'woman',
#    'physicist',
#    'chemist',
#    'biologist',
#    'scientist'],
#   'definition': 'The Female Scientist Type-3 emoji sequence Woman Emoji Modifier Fitzpatrick Type-3 Microscope emojis These c'},
#  'U+1F60D': {'name': 'smiling face with heart-eyes',
#   'keywords': ['eye', 'smile', 'love', 'face'],
#   'definition': 'A face hearts instead eyes Heart Eyes Emoji generally known \xa0 Used expression love example \xa0  “ I love ”  '},
#  'U+1F60C': {'name': 'relieved face',
#   'keywords': ['relieved', 'face'],
#   'definition': 'Pleasantly content Happy \xa0 Feeling sense relief \xa0 situation convey calm content state mind R'},
#  'U+1F60B': {'name': 'face savouring delicious food',
#   'keywords': ['savouring', 'smile', 'yum', 'um', 'delicious', 'face'],
#   'definition': 'A friendly goofy smile tongue hanging mouth Used indicate silly happiness Face Savouring Delicious Food'},
#  'U+1F60A': {'name': 'smiling face with smiling eyes',
#   'keywords': ['eye', 'smile', 'face', 'blush'],
#   'definition': 'A smiling face smiling eyes rosy cheeks Showing true sense happiness This emoji smiles mouth closed makes'},
#  'U+1F609': {'name': 'winking face',
#   'keywords': ['wink', 'face'],
#   'definition': 'A classic winky emoji winking smiling Used \xa0 imply humor written form alternatively suggestively form fl'},
#  'U+1F469 U+1F3FC U+200D U+1F527': {'name': 'woman mechanic: medium-light skin tone',
#   'keywords': ['electrician',
#    'tradesperson',
#    'medium-light skin tone',
#    'plumber',
#    'woman',
#    'mechanic'],
#   'definition': 'The Female Mechanic Type-3 emoji sequence Woman Emoji Modifier Fitzpatrick Type-3 Wrench emojis These combin'},
#  'U+1F608': {'name': 'smiling face with horns',
#   'keywords': ['smile', 'fairy tale', 'horns', 'fantasy', 'face'],
#   'definition': 'A smiling devil like face \xa0 Has evil looking smiling face inward facing eyebrows In Apple artwork appears purple nearly'},
#  'U+1F607': {'name': 'smiling face with halo',
#   'keywords': ['innocent',
#    'smile',
#    'fairy tale',
#    'fantasy',
#    'face',
#    'halo',
#    'angel'],
#   'definition': 'A face halo represent angel good person person good deed Smiling Face With Halo appr'},
#  'U+1F606': {'name': 'smiling face with open mouth & closed eyes',
#   'keywords': ['laugh', 'smile', 'mouth', 'open', 'face', 'satisfied'],
#   'definition': 'A face big smiling mouth scrunched closed eyes May similar context text based \xa0 emoticon Smiling Face Wit'},
#  'U+1F605': {'name': 'smiling face with open mouth & cold sweat',
#   'keywords': ['cold', 'smile', 'open', 'sweat', 'face'],
#   'definition': 'The face \xa0 Smiling Face With Open Mouth And Smiling Eyes single drop sweat face A rarely emoji'},
#  'U+1F604': {'name': 'smiling face with open mouth & smiling eyes',
#   'keywords': ['eye', 'smile', 'mouth', 'open', 'face'],
#   'definition': 'A happy smiling face \xa0 big open mouth showing teeth Differs slightly \xa0 Smiling Face With Open Mouth \xa0 emoji fact t'},
#  'U+1F603': {'name': 'smiling face with open mouth',
#   'keywords': ['smile', 'mouth', 'open', 'face'],
#   'definition': 'A \xa0 classic smiley face emoji \xa0 \xa0 open mouth showing teeth tall \xa0 open eyes \xa0 Differs slightly \xa0 Smiling Face With Open Mou'},
#  'U+1F602': {'name': 'face with tears of joy',
#   'keywords': ['laugh', 'joy', 'face', 'tear'],
#   'definition': 'A laughing emoji \xa0 \xa0 small sizes mistaken tears sadness \xa0 This emoji laughing crying tears o'},
#  'U+1F601': {'name': 'grinning face with smiling eyes',
#   'keywords': ['eye', 'smile', 'grin', 'face'],
#   'definition': 'A version \xa0 grinning face \xa0 showing smiling eyes This emoji \xa0 previously looked closer \xa0 grimacing face \xa0 platforms'},
#  'U+1F600': {'name': 'grinning face',
#   'keywords': ['grin', 'face'],
#   'definition': 'A face big open grinning mouth showing teeth \xa0 Differs slightly \xa0 Smiling Face With Open Mouth And Smiling Eyes \xa0  '},
#  'U+1F3CA U+1F3FE U+200D U+2640 U+FE0F': {'name': 'woman swimming: medium-dark skin tone',
#   'keywords': ['swim', 'medium-dark skin tone', 'woman'],
#   'definition': 'The Woman Swimming Type-5 emoji sequence Swimmer Emoji Modifier Fitzpatrick Type-5 Female Sign Variation Select'},
#  'U+1F487 U+1F3FF U+200D U+2640 U+FE0F': {'name': 'woman getting haircut: dark skin tone',
#   'keywords': ['dark skin tone', 'woman', 'haircut'],
#   'definition': 'The Woman Getting Haircut Type-6 emoji sequence Haircut Emoji Modifier Fitzpatrick Type-6 Female Sign Variation'},
#  'U+1F575 U+1F3FE U+200D U+2642 U+FE0F': {'name': 'man detective: medium-dark skin tone',
#   'keywords': ['sleuth', 'spy', 'medium-dark skin tone', 'detective', 'man'],
#   'definition': 'The Male Sleuth Type-5 emoji sequence Sleuth Spy Emoji Modifier Fitzpatrick Type-5 Male Sign Variation Selec'},
#  'U+1F471 U+1F3FF U+200D U+2642 U+FE0F': {'name': 'blond-haired man: dark skin tone',
#   'keywords': ['dark skin tone', 'blond', 'man'],
#   'definition': 'The Blond Man Type-6 emoji sequence Person With Blond Hair Emoji Modifier Fitzpatrick Type-6 Male Sign Variatio'},
#  'U+1F6B4 U+1F3FD U+200D U+2640 U+FE0F': {'name': 'woman biking: medium skin tone',
#   'keywords': ['bicycle', 'cyclist', 'woman', 'biking', 'medium skin tone'],
#   'definition': 'The Woman Biking Type-4 emoji sequence Bicyclist Emoji Modifier Fitzpatrick Type-4 Female Sign Variation Select'},
#  'U+1F468 U+1F3FC U+200D U+2708 U+FE0F': {'name': 'man pilot: medium-light skin tone',
#   'keywords': ['plane', 'medium-light skin tone', 'pilot', 'man'],
#   'definition': 'The Male Pilot Type-3 emoji sequence Man Emoji Modifier Fitzpatrick Type-3 Airplane Variation Selector-16 emoji'},
#  ...}

# %% [markdown]
# To search the emoji inside EmojiNet, we need to convert each emoji into a string of unicode.

# %%
def emoji2unicode_str(e):
    return " ".join(['U+{:X}'.format(ord(c)) for c in e])

# %%
e = "💃🏻"
emoji2unicode_str(e)
# Out:
# 'U+1F483 U+1F3FB'

# %%
i = 0
for e in vocab:
    if e == "PAD":
        continue
    unicode = emoji2unicode_str(e)
    if unicode in emojinet:
        i += 1

print("Vocab size for emoji2vec:", len(vocab))
print("Number of emojies covered by EmojiNet:", i)
# Out:
# Vocab size for emoji2vec: 1662
# Number of emojies covered by EmojiNet: 1519

# %% [markdown]
# Generate new training samples using the descriptions and keywords from EmojiNet

# %%
"""
Generate new samples using the description and keywords.
"""

desc_list = []
emoji_list = []
keyword_list = []

for e in vocab:
    unicode = emoji2unicode_str(e)
    if unicode not in emojinet:
        continue
    desc_list.append(emojinet[unicode]["definition"])
    emoji_list.append(e)
    keyword_list.append(" ".join(emojinet[unicode]["keywords"]))

labels = [1 for i in range(len(emoji_list))]

desc_df = pd.DataFrame({"description": desc_list, "emoji": emoji_list, "label": labels})
keyword_df = pd.DataFrame({"keywords": keyword_list, "emoji": emoji_list, "label": labels})

# %%
desc_df
# Out:
#                                             description emoji  label
# 0     A person swimming pool ocean body water   Lack...     🏊      1
# 1     This version Woman Dancing emoji Light Skin To...    💃🏻      1
# 2     Black Large Square approved Unicode 5.1 2008 a...     ⬛      1
# 3     A mobile phone   referred cellular cell phone ...     📱      1
# 4     The flag   Jamaica letters   JM   platforms Th...    🇯🇲      1
# ...                                                 ...   ...    ...
# 1514  A bar chart showing comparison figures data Ba...     📊      1
# 1515  This version Baby Angel emoji Medium dark Skin...    👼🏾      1
# 1516  An embarrassed face   flushed red cheeks   Thi...     😳      1
# 1517  A large ship transport people cargo ocean May ...     🚢      1
# 1518  A shrine Japanese Shinto religion This emoji g...     ⛩      1
#
# [1519 rows x 3 columns]

# %%
keyword_df
# Out:
#                                                keywords emoji  label
# 0                                                  swim     🏊      1
# 1                         light skin tone dancing woman    💃🏻      1
# 2                                      square geometric     ⬛      1
# 3                           cell phone telephone mobile     📱      1
# 4                                                  flag    🇯🇲      1
# ...                                                 ...   ...    ...
# 1514                                    chart bar graph     📊      1
# 1515  fairy tale medium-dark skin tone fantasy face ...    👼🏾      1
# 1516                                 flushed face dazed     😳      1
# 1517                                     passenger boat     🚢      1
# 1518                             religion shinto shrine     ⛩      1
#
# [1519 rows x 3 columns]

# %%
desc_df.to_csv(current_path / "data" / "train_desc.txt", sep="\t", index=False, header=False)

# %%
keyword_df.to_csv(current_path / "data" / "train_keyword.txt", sep="\t", index=False, header=False)
